# %%
import pandas as pd
import time
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# /tmp/ipykernel_23263/1503906442.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
page_url = 'https://www.dota2.com/heroes'
driver.get(page_url)

# %%
title = driver.title
print(title)
# Out:
# Dota 2 Heroes

# %% [markdown]
# ## Get Heroes link ##

# %%
from selenium.webdriver.common.by import By
import re

# get all heroes
heroes_elms = driver.find_elements(By.CLASS_NAME, 'herogridpage_HeroIcon_7szOn')

# get name and link of hero
heroes = [{'name':hero.get_attribute('href').split('/')[-1],'link':hero.get_attribute('href')} for hero in heroes_elms]

# %% [markdown]
# ## Get Heroes Attribute ##

# %%
# Function to get all hero attribute
def get_hero_attributes(hero_dict):
    # get link
    driver.get(hero_dict.get('link'))  
    driver.implicitly_wait(5)
    
    # get basic attribute
    get_basic_attribute(hero_dict, 'heropage_AttributeValue_3Gsgg', 'Base')
    get_basic_attribute(hero_dict, 'heropage_AttributeGain_DpX1z', 'Gain')
    
    # Get value element
    get_value_element(hero_dict, 'heropage_ValueElement_3783T')

# Get basic attribute
def get_basic_attribute(hero_dict, class_name, prefix):
    
    # basic attribute
    basis = ['Strength','Agility','Inteligence']
    
    # Get attribute element
    attributes = driver.find_elements(By.CLASS_NAME, class_name)
    
    for i in range(len(attributes)):
        hero_dict[prefix + basis[i]] = float(attributes[i].text)
    
# Get atribute name
def get_attribute_name(elm):
    
    # get elment name
    name = elm.find_element(By.CLASS_NAME,'heropage_SwordIcon_FY7TW').get_attribute('src')
    
    return '_'.join(name.split('/')[-1].split('.')[0].split('_')[1:])

# Get value element
def get_value_element(hero_dict, class_name):
    
    # Get attribute element
    values = driver.find_elements(By.CLASS_NAME, class_name)
    if len(driver.find_elements(By.CLASS_NAME, 'heropage_SwordIcon_FY7TW'))>8:
        for i in range(9):
            hero_dict[get_attribute_name(values[i])] = values[i].text
    else:
        for i in range(8):
            hero_dict[get_attribute_name(values[i])] = values[i].text
        hero_dict['projectile_speed'] = ''

# %%
# get hero attribute
list(map(get_hero_attributes, heroes))
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
heroes_attributes_df = pd.DataFrame(heroes)

# %%
heroes_attributes_df
# Out:
#                   name                                          link  \
# 0              abaddon            https://www.dota2.com/hero/abaddon
# 1            alchemist          https://www.dota2.com/hero/alchemist
# 2    ancientapparition  https://www.dota2.com/hero/ancientapparition
# 3            anti-mage          https://www.dota2.com/hero/anti-mage
# 4            arcwarden          https://www.dota2.com/hero/arcwarden
# ..                 ...                                           ...
# 118         windranger         https://www.dota2.com/hero/windranger
# 119       winterwyvern       https://www.dota2.com/hero/winterwyvern
# 120        witchdoctor        https://www.dota2.com/hero/witchdoctor
# 121         wraithking         https://www.dota2.com/hero/wraithking
# 122               zeus               https://www.dota2.com/hero/zeus
#
#      Strength  Agility  Inteligence  GainStrength  GainAgility  \
# 0        22.0     23.0         18.0           2.6          1.5
# 1        23.0     22.0         25.0           2.7          1.5
# 2        20.0     20.0         23.0           1.9          2.2
# 3        21.0     24.0         12.0           1.6          2.8
# 4        22.0     20.0         24.0           2.6          3.0
# ..        ...      ...          ...           ...          ...
# 118      18.0     17.0         18.0           2.6          1.4
# 119      22.0     16.0         26.0           2.5          1.7
# 120      18.0     13.0         22.0           2.3          1.4
# 121      22.0     16.0         18.0           3.0          1.7
# 122      19.0     11.0         22.0           2.1          1.2
#
#      GainInteligence damage attack_time attack_range projectile_speed armor  \
# 0                2.0  50-60         1.7          150              900   2.8
# 1                1.8  50-56         1.7          150              900   2.7
# 2                3.4  44-54         1.7          675             1250   2.3
# 3                1.8  53-57         1.4          150                    4.0
# 4                2.6  51-57         1.7          625              900   2.3
# ..               ...    ...         ...          ...              ...   ...
# 118              3.6  42-54         1.5          600             1250   1.8
# 119              3.6  40-47         1.7          425              700   2.7
# 120              3.3  51-61         1.7          550             1200   2.2
# 121              1.6  60-62         1.7          150                    1.7
# 122              3.3  55-63         1.7          380             1100   3.8
#
#     magic_resist movement_speed turn_rate      vision
# 0            25%            325       0.6  1800 / 800
# 1            25%            305       0.6  1800 / 800
# 2            25%            285       0.6  1800 / 800
# 3            25%            310       0.6  1800 / 800
# 4            25%            285       0.7  1800 / 800
# ..           ...            ...       ...         ...
# 118          25%            290       0.8  1800 / 800
# 119          25%            285       0.6  1800 / 800
# 120          25%            300       0.6  1800 / 800
# 121          25%            315       0.6  1800 / 800
# 122          25%            315       0.6  1800 / 800
#
# [123 rows x 17 columns]

# %% [markdown]
# ### Process data ###

# %% [raw]
# In this step, I will process the data. For example, turn 25% -> 0.25 or turn range 40-50 to its mean 45, ...
